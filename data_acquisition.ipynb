# %%
import kagglehub
import shutil
import os

# %%
download_path = kagglehub.dataset_download("codewithsk/tomato-leaf-disease-from-plantcity-2025")
dst = os.getcwd().replace('\\', '/') + '/data/raw/'

os.makedirs(dst, exist_ok=True)

for item in os.listdir(download_path):
    shutil.move(os.path.join(download_path, item), os.path.join(dst, item))
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/codewithsk/tomato-leaf-disease-from-plantcity-2025?dataset_version_number=1...
# 100%|██████████| 1.86G/1.86G [00:57<00:00, 34.7MB/s]
# Extracting files...
